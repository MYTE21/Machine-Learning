# %% [markdown]
# ---
# **Pizza size vs prices**
#
#
# ---

# %% [markdown]
# **Import Files :**
#
# *   Linear Regression (Numerical Analysis).ipynb

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d37f7b1b-e38f-433a-b687-29ad54ac58fb" name="files[]" multiple disabled />
#      <output id="result-d37f7b1b-e38f-433a-b687-29ad54ac58fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Linear Regression (Numerical Analysis).csv to Linear Regression (Numerical Analysis).csv

# %% [markdown]
# **Load csv file**

# %%
import pandas as pd
data = pd.read_csv('Linear Regression (Numerical Analysis).csv')
print(data.head())
# Out:
#    Size  Price
# 0     6    350
# 1     8    775
# 2    12   1150
# 3    14   1395
# 4    18   1675

# %% [markdown]
# **Plot data**

# %%
import matplotlib.pyplot as plt
plt.scatter(data.Size, data.Price)
plt.show()

# %% [markdown]
# **Modify data**

# %%
data = data.rename(
              columns=
              {
                'Size': 'X',
                'Price': 'Y'
              })

data.insert(2, 'XY', X*Y)
data.insert(3, 'X^2', X**2)

print(data)
# Out:
#     X     Y     XY  X^2
# 0   6   350   2100   36
# 1   8   775   6200   64
# 2  12  1150  13800  144
# 3  14  1395  19530  196
# 4  18  1675  30150  324
